# %%
import pandas as pd

# %% [markdown]
# # ----------------------------------------- Insurance ------------------------------------------------------

# %%
ins=pd.read_csv('insurance.csv')
ins
# Out:
#         id  age     sex     bmi  children smoker     region      charges
# 0     1001   19  female  27.900         0    yes  southwest  16884.92400
# 1     1002   18    male  33.770         1     no  southeast   1725.55230
# 2     1003   28    male  33.000         3     no  southeast   4449.46200
# 3     1004   33    male  22.705         0     no  northwest  21984.47061
# 4     1005   32    male  28.880         0     no  northwest   3866.85520
# ...    ...  ...     ...     ...       ...    ...        ...          ...
# 1333  2334   50    male  30.970         3     no  northwest  10600.54830
# 1334  2335   18  female  31.920         0     no  northeast   2205.98080
# 1335  2336   18  female  36.850         0     no  southeast   1629.83350
# 1336  2337   21  female  25.800         0     no  southwest   2007.94500
# 1337  2338   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 8 columns]

# %% [markdown]
# #### Count for each categories of ‘region

# %%
ins.groupby('region').count()
# Out:
#             id  age  sex  bmi  children  smoker  charges
# region
# northeast  324  324  324  324       324     324      324
# northwest  325  325  325  325       325     325      325
# southeast  364  364  364  364       364     364      364
# southwest  325  325  325  325       325     325      325

# %% [markdown]
# #### Find 50 records of highest ‘age’ and export data/table to desktop

# %%
ins.sort_values('age',ascending=False).head(50)
# Out:
#         id  age     sex     bmi  children smoker     region      charges
# 335   1336   64    male  34.500         0     no  southwest  13822.80300
# 603   1604   64  female  39.050         3     no  southeast  16085.12750
# 752   1753   64    male  37.905         0     no  northwest  14210.53595
# 1265  2266   64    male  23.760         0    yes  southeast  26926.51440
# 534   1535   64    male  40.480         0     no  southeast  13831.11520
# 328   1329   64  female  33.800         1    yes  southwest  47928.03000
# 768   1769   64  female  39.700         0     no  southwest  14319.03100
# 1241  2242   64    male  36.960         2    yes  southeast  49577.66240
# 62    1063   64    male  24.700         1     no  northwest  30166.61817
# 801   1802   64  female  35.970         0     no  southeast  14313.84630
# 825   1826   64  female  31.825         2     no  northeast  16069.08475
# 378   1379   64  female  30.115         3     no  northwest  16455.70785
# ...

# %% [markdown]
# #### Add index name ‘quick’ on ‘id’

# %%
ins.set_index('id')
# Out:
#       age     sex     bmi  children smoker     region      charges
# id
# 1001   19  female  27.900         0    yes  southwest  16884.92400
# 1002   18    male  33.770         1     no  southeast   1725.55230
# 1003   28    male  33.000         3     no  southeast   4449.46200
# 1004   33    male  22.705         0     no  northwest  21984.47061
# 1005   32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 2334   50    male  30.970         3     no  northwest  10600.54830
# 2335   18  female  31.920         0     no  northeast   2205.98080
# 2336   18  female  36.850         0     no  southeast   1629.83350
# 2337   21  female  25.800         0     no  southwest   2007.94500
# 2338   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# #### Describe the schema of table

# %%
ins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        1338 non-null   int64
#  1   age       1338 non-null   int64
#  2   sex       1338 non-null   object
#  3   bmi       1338 non-null   float64
#  4   children  1338 non-null   int64
#  5   smoker    1338 non-null   object
#  6   region    1338 non-null   object
#  7   charges   1338 non-null   float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 83.8+ KB

# %% [markdown]
# #### Create view name as ‘gender’ where users can not see ‘sex’ [Hint: first run appropriate query then create view]

# %%
gender=ins[[	'id','age','bmi','children','smoker','region','charges']]
gender
# Out:
#         id  age     bmi  children smoker     region      charges
# 0     1001   19  27.900         0    yes  southwest  16884.92400
# 1     1002   18  33.770         1     no  southeast   1725.55230
# 2     1003   28  33.000         3     no  southeast   4449.46200
# 3     1004   33  22.705         0     no  northwest  21984.47061
# 4     1005   32  28.880         0     no  northwest   3866.85520
# ...    ...  ...     ...       ...    ...        ...          ...
# 1333  2334   50  30.970         3     no  northwest  10600.54830
# 1334  2335   18  31.920         0     no  northeast   2205.98080
# 1335  2336   18  36.850         0     no  southeast   1629.83350
# 1336  2337   21  25.800         0     no  southwest   2007.94500
# 1337  2338   61  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# #### Rename the view as ‘type’

# %%
view=gender.copy(deep=True)
view
# Out:
#         id  age     bmi  children smoker     region      charges
# 0     1001   19  27.900         0    yes  southwest  16884.92400
# 1     1002   18  33.770         1     no  southeast   1725.55230
# 2     1003   28  33.000         3     no  southeast   4449.46200
# 3     1004   33  22.705         0     no  northwest  21984.47061
# 4     1005   32  28.880         0     no  northwest   3866.85520
# ...    ...  ...     ...       ...    ...        ...          ...
# 1333  2334   50  30.970         3     no  northwest  10600.54830
# 1334  2335   18  31.920         0     no  northeast   2205.98080
# 1335  2336   18  36.850         0     no  southeast   1629.83350
# 1336  2337   21  25.800         0     no  southwest   2007.94500
# 1337  2338   61  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# #### Count how many are ‘northwest’ insurance holders

# %%
ins[ins['region']=='northwest'].count()
# Out:
# id          325
# age         325
# sex         325
# bmi         325
# children    325
# smoker      325
# region      325
# charges     325
# dtype: int64

# %% [markdown]
# #### Count how many insurance holders were ‘female’

# %%
ins.value_counts('sex').get('female',0)
# Out:
# 662

# %% [markdown]
# #### Create Primary key on a suitable column

# %%
ins
ins.set_index('id')
# as its unique and is not null
# Out:
#       age     sex     bmi  children smoker     region      charges
# id
# 1001   19  female  27.900         0    yes  southwest  16884.92400
# 1002   18    male  33.770         1     no  southeast   1725.55230
# 1003   28    male  33.000         3     no  southeast   4449.46200
# 1004   33    male  22.705         0     no  northwest  21984.47061
# 1005   32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 2334   50    male  30.970         3     no  northwest  10600.54830
# 2335   18  female  31.920         0     no  northeast   2205.98080
# 2336   18  female  36.850         0     no  southeast   1629.83350
# 2337   21  female  25.800         0     no  southwest   2007.94500
# 2338   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# #### Create a new column ‘ratio’ which is age multiply by bmi

# %%
ins['ratio']=ins['age'] * ins['bmi']
ins
# Out:
#         id  age     sex     bmi  children smoker     region      charges  \
# 0     1001   19  female  27.900         0    yes  southwest  16884.92400
# 1     1002   18    male  33.770         1     no  southeast   1725.55230
# 2     1003   28    male  33.000         3     no  southeast   4449.46200
# 3     1004   33    male  22.705         0     no  northwest  21984.47061
# 4     1005   32    male  28.880         0     no  northwest   3866.85520
# ...    ...  ...     ...     ...       ...    ...        ...          ...
# 1333  2334   50    male  30.970         3     no  northwest  10600.54830
# 1334  2335   18  female  31.920         0     no  northeast   2205.98080
# 1335  2336   18  female  36.850         0     no  southeast   1629.83350
# 1336  2337   21  female  25.800         0     no  southwest   2007.94500
# 1337  2338   61  female  29.070         0    yes  northwest  29141.36030
#
#          ratio
# 0      530.100
# 1      607.860
# 2      924.000
# 3      749.265
# ...

# %% [markdown]
# #### Arrange the table from high to low according to charges

# %%
ins.sort_values('charges',ascending=False)
# Out:
#         id  age     sex     bmi  children smoker     region      charges  \
# 543   1544   54  female  47.410         0    yes  southeast  63770.42801
# 1300  2301   45    male  30.360         0    yes  southeast  62592.87309
# 1230  2231   52    male  34.485         3    yes  northwest  60021.39897
# 577   1578   31  female  38.095         1    yes  northeast  58571.07448
# 819   1820   33  female  35.530         0    yes  northwest  55135.40209
# ...    ...  ...     ...     ...       ...    ...        ...          ...
# 22    1023   18    male  34.100         0     no  southeast   1137.01100
# 663   1664   18    male  33.660         0     no  southeast   1136.39940
# 1244  2245   18    male  33.330         0     no  southeast   1135.94070
# 808   1809   18    male  30.140         0     no  southeast   1131.50660
# 940   1941   18    male  23.210         0     no  southeast   1121.87390
#
#          ratio
# 543   2560.140
# 1300  1366.200
# 1230  1793.220
# 577   1180.945
# ...

# %% [markdown]
# #### Find MAX of ‘charges’

# %%
ins.charges.max()
# Out:
# 63770.42801

# %% [markdown]
# #### Find MIN of ‘charges’

# %%
ins.charges.min()
# Out:
# 1121.8739

# %% [markdown]
# #### Find average of ‘charges’ of male and female

# %%
ins.groupby('sex')['charges'].mean()
# Out:
# sex
# female    12569.578844
# male      13956.751178
# Name: charges, dtype: float64

# %% [markdown]
# #### Write a Query to rename column name sex to Gender

# %%
ins.rename(columns={'sex':'gender'},inplace=True)
ins
# Out:
#         id  age  gender     bmi  children smoker     region      charges  \
# 0     1001   19  female  27.900         0    yes  southwest  16884.92400
# 1     1002   18    male  33.770         1     no  southeast   1725.55230
# 2     1003   28    male  33.000         3     no  southeast   4449.46200
# 3     1004   33    male  22.705         0     no  northwest  21984.47061
# 4     1005   32    male  28.880         0     no  northwest   3866.85520
# ...    ...  ...     ...     ...       ...    ...        ...          ...
# 1333  2334   50    male  30.970         3     no  northwest  10600.54830
# 1334  2335   18  female  31.920         0     no  northeast   2205.98080
# 1335  2336   18  female  36.850         0     no  southeast   1629.83350
# 1336  2337   21  female  25.800         0     no  southwest   2007.94500
# 1337  2338   61  female  29.070         0    yes  northwest  29141.36030
#
#          ratio
# 0      530.100
# 1      607.860
# 2      924.000
# 3      749.265
# ...

# %% [markdown]
# #### Add new column as HL_Charges where more than average charges should be categorized as HIGH and less than average charges should be categorized as LOW

# %%
ins['HL_Charges']=ins['charges'].apply(lambda x : "High" if x>ins['charges'].mean()  else  'Low')
ins
# Out:
#         id  age  gender     bmi  children smoker     region      charges  \
# 0     1001   19  female  27.900         0    yes  southwest  16884.92400
# 1     1002   18    male  33.770         1     no  southeast   1725.55230
# 2     1003   28    male  33.000         3     no  southeast   4449.46200
# 3     1004   33    male  22.705         0     no  northwest  21984.47061
# 4     1005   32    male  28.880         0     no  northwest   3866.85520
# ...    ...  ...     ...     ...       ...    ...        ...          ...
# 1333  2334   50    male  30.970         3     no  northwest  10600.54830
# 1334  2335   18  female  31.920         0     no  northeast   2205.98080
# 1335  2336   18  female  36.850         0     no  southeast   1629.83350
# 1336  2337   21  female  25.800         0     no  southwest   2007.94500
# 1337  2338   61  female  29.070         0    yes  northwest  29141.36030
#
#          ratio HL_Charges
# 0      530.100       High
# 1      607.860        Low
# ...

# %% [markdown]
# #### Change location/position of ‘smoker’ and bring before ‘children’

# %%
ins=ins[['id', 'age', 'gender', 'bmi', 'smoker','children',  'region', 'charges', 'ratio', 'HL_Charges']]
ins
# Out:
#         id  age  gender     bmi smoker  children     region      charges  \
# 0     1001   19  female  27.900    yes         0  southwest  16884.92400
# 1     1002   18    male  33.770     no         1  southeast   1725.55230
# 2     1003   28    male  33.000     no         3  southeast   4449.46200
# 3     1004   33    male  22.705     no         0  northwest  21984.47061
# 4     1005   32    male  28.880     no         0  northwest   3866.85520
# ...    ...  ...     ...     ...    ...       ...        ...          ...
# 1333  2334   50    male  30.970     no         3  northwest  10600.54830
# 1334  2335   18  female  31.920     no         0  northeast   2205.98080
# 1335  2336   18  female  36.850     no         0  southeast   1629.83350
# 1336  2337   21  female  25.800     no         0  southwest   2007.94500
# 1337  2338   61  female  29.070    yes         0  northwest  29141.36030
#
#          ratio HL_Charges
# 0      530.100       High
# 1      607.860        Low
# ...

# %% [markdown]
# #### Show top 20 records

# %%
ins.head(20)
# Out:
#       id  age  gender     bmi smoker  children     region      charges  \
# 0   1001   19  female  27.900    yes         0  southwest  16884.92400
# 1   1002   18    male  33.770     no         1  southeast   1725.55230
# 2   1003   28    male  33.000     no         3  southeast   4449.46200
# 3   1004   33    male  22.705     no         0  northwest  21984.47061
# 4   1005   32    male  28.880     no         0  northwest   3866.85520
# 5   1006   31  female  25.740     no         0  southeast   3756.62160
# 6   1007   46  female  33.440     no         1  southeast   8240.58960
# 7   1008   37  female  27.740     no         3  northwest   7281.50560
# 8   1009   37    male  29.830     no         2  northeast   6406.41070
# 9   1010   60  female  25.840     no         0  northwest  28923.13692
# 10  1011   25    male  26.220     no         0  northeast   2721.32080
# 11  1012   62  female  26.290    yes         0  southeast  27808.72510
# ...

# %% [markdown]
# #### Show bottom 20 records

# %%
ins.tail(20)
# Out:
#         id  age  gender     bmi smoker  children     region      charges  \
# 1318  2319   35    male  39.710     no         4  northeast  19496.71917
# 1319  2320   39  female  26.315     no         2  northwest   7201.70085
# 1320  2321   31    male  31.065     no         3  northwest   5425.02335
# 1321  2322   62    male  26.695    yes         0  northeast  28101.33305
# 1322  2323   62    male  38.830     no         0  southeast  12981.34570
# 1323  2324   42  female  40.370    yes         2  southeast  43896.37630
# 1324  2325   31    male  25.935     no         1  northwest   4239.89265
# 1325  2326   61    male  33.535     no         0  northeast  13143.33665
# 1326  2327   42  female  32.870     no         0  northeast   7050.02130
# 1327  2328   51    male  30.030     no         1  southeast   9377.90470
# 1328  2329   23  female  24.225     no         2  northeast  22395.74424
# 1329  2330   52    male  38.600     no         2  southwest  10325.20600
# ...

# %% [markdown]
# #### Randomly select 20% of records

# %%
samp=ins.sample(frac=0.2)
samp
# Out:
#         id  age  gender    bmi smoker  children     region     charges  \
# 18    1019   56    male  40.30     no         0  southwest  10602.3850
# 1305  2306   24  female  27.72     no         0  southeast   2464.6188
# 1241  2242   64    male  36.96    yes         2  southeast  49577.6624
# 711   1712   50  female  23.54     no         2  southeast  10107.2206
# 470   1471   27    male  32.67     no         0  southeast   2497.0383
# ...    ...  ...     ...    ...    ...       ...        ...         ...
# 1034  2035   61    male  38.38     no         0  northwest  12950.0712
# 320   1321   34    male  25.27     no         1  northwest   4894.7533
# 225   1226   55    male  33.88     no         3  southeast  11987.1682
# 1000  2001   30    male  22.99    yes         2  northwest  17361.7661
# 86    1087   57  female  31.16    yes         0  northwest  43578.9394
#
#         ratio HL_Charges
# 18    2256.80        Low
# 1305   665.28        Low
# 1241  2365.44       High
# ...

# %% [markdown]
# #### Remove column ‘ratio’

# %%
ins.drop(columns='ratio')
# Out:
#         id  age  gender     bmi smoker  children     region      charges  \
# 0     1001   19  female  27.900    yes         0  southwest  16884.92400
# 1     1002   18    male  33.770     no         1  southeast   1725.55230
# 2     1003   28    male  33.000     no         3  southeast   4449.46200
# 3     1004   33    male  22.705     no         0  northwest  21984.47061
# 4     1005   32    male  28.880     no         0  northwest   3866.85520
# ...    ...  ...     ...     ...    ...       ...        ...          ...
# 1333  2334   50    male  30.970     no         3  northwest  10600.54830
# 1334  2335   18  female  31.920     no         0  northeast   2205.98080
# 1335  2336   18  female  36.850     no         0  southeast   1629.83350
# 1336  2337   21  female  25.800     no         0  southwest   2007.94500
# 1337  2338   61  female  29.070    yes         0  northwest  29141.36030
#
#      HL_Charges
# 0          High
# 1           Low
# 2           Low
# 3          High
# ...

# %% [markdown]
# #### Craete one example of Sub Queries involving ‘bmi’ and ‘sex’ and give explanation in the script itself with remarks by using

# %%
ins.head()
# Out:
#      id  age  gender     bmi smoker  children     region      charges  \
# 0  1001   19  female  27.900    yes         0  southwest  16884.92400
# 1  1002   18    male  33.770     no         1  southeast   1725.55230
# 2  1003   28    male  33.000     no         3  southeast   4449.46200
# 3  1004   33    male  22.705     no         0  northwest  21984.47061
# 4  1005   32    male  28.880     no         0  northwest   3866.85520
#
#      ratio HL_Charges
# 0  530.100       High
# 1  607.860        Low
# 2  924.000        Low
# 3  749.265       High
# 4  924.160        Low

# %%
ins[(ins['age']==19)& (ins['bmi']==27.900)][['id','ratio']]
# Out:
#      id  ratio
# 0  1001  530.1

# %% [markdown]
# #### Create a view called Female_HL_Charges that shows only those data where HL_Charges is High, Female, Smokers and with 0 children

# %%
Female_HL_Charges=ins[(ins['HL_Charges']=='High')& (ins['gender']=='female')& (ins['smoker']=='yes' )& (ins['children']==0 )][['id', 'age', 'gender', 'bmi', 'smoker', 'children', 'region', 'charges', 'ratio', 'HL_Charges']]
Female_HL_Charges
# Out:
#         id  age  gender     bmi smoker  children     region      charges  \
# 0     1001   19  female  27.900    yes         0  southwest  16884.92400
# 11    1012   62  female  26.290    yes         0  southeast  27808.72510
# 64    1065   20  female  22.420    yes         0  northwest  14711.74380
# 70    1071   27  female  24.750    yes         0  southeast  16577.77950
# 86    1087   57  female  31.160    yes         0  northwest  43578.93940
# 126   1127   19  female  28.300    yes         0  southwest  17081.08000
# 153   1154   42  female  23.370    yes         0  northeast  19964.74630
# 160   1161   42  female  26.600    yes         0  northwest  21348.70600
# 161   1162   18  female  36.850    yes         0  southeast  36149.48350
# 175   1176   63  female  37.700    yes         0  southwest  48824.45000
# 203   1204   27  female  36.080    yes         0  southeast  37133.89820
# 244   1245   63  female  27.740    yes         0  northeast  29523.16560
# ...

# %% [markdown]
# #### Update children column if there is 0 children then make it as Zero Children, if 1 then one_children, if 2 then two_children, if 3 then three_children, if 4 then four_children if 5 then five_children else print it as More_than_five_children.

# %%
ins['children']=ins.children.apply(lambda x : "ZERO" if x==0 else "one_children" if x==1 else "two_children" if x==2 else "three_children" if x==3 else "four_children" if x==4 else "More_than_five_children")

# %%
ins
# Out:
#         id  age  gender     bmi smoker        children     region  \
# 0     1001   19  female  27.900    yes            ZERO  southwest
# 1     1002   18    male  33.770     no    one_children  southeast
# 2     1003   28    male  33.000     no  three_children  southeast
# 3     1004   33    male  22.705     no            ZERO  northwest
# 4     1005   32    male  28.880     no            ZERO  northwest
# ...    ...  ...     ...     ...    ...             ...        ...
# 1333  2334   50    male  30.970     no  three_children  northwest
# 1334  2335   18  female  31.920     no            ZERO  northeast
# 1335  2336   18  female  36.850     no            ZERO  southeast
# 1336  2337   21  female  25.800     no            ZERO  southwest
# 1337  2338   61  female  29.070    yes            ZERO  northwest
#
#           charges     ratio HL_Charges
# 0     16884.92400   530.100       High
# 1      1725.55230   607.860        Low
# 2      4449.46200   924.000        Low
# ...

# %% [markdown]
# # END
